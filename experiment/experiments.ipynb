# %%
import pandas as pd

pd.set_option('display.max_columns', 500)

import os
os.chdir(r"C:\Notes\ds_project_portfolio\supply-chain-shipment-pricing-prediction")

# %%
path=r"data\SCMS_Delivery_History_Dataset.csv"
df=pd.read_csv(path,index_col='ID')

# %%
df.head()
# Out:
#    Project Code            PQ # PO / SO # ASN/DN #        Country Managed By  \
# ID
# 1    100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte d'Ivoire   PMO - US
# 3    108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam   PMO - US
# 4    100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte d'Ivoire   PMO - US
# 15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam   PMO - US
# 16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam   PMO - US
#
#     Fulfill Via Vendor INCO Term Shipment Mode PQ First Sent to Client Date  \
# ID
# 1   Direct Drop              EXW           Air               Pre-PQ Process
# 3   Direct Drop              EXW           Air               Pre-PQ Process
# 4   Direct Drop              FCA           Air               Pre-PQ Process
# 15  Direct Drop              EXW           Air               Pre-PQ Process
# 16  Direct Drop              EXW           Air               Pre-PQ Process
#
# ...

# %%
df.shape
# Out:
# (10324, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10324 entries, 1 to 86823
# Data columns (total 32 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Project Code                  10324 non-null  object
#  1   PQ #                          10324 non-null  object
#  2   PO / SO #                     10324 non-null  object
#  3   ASN/DN #                      10324 non-null  object
#  4   Country                       10324 non-null  object
#  5   Managed By                    10324 non-null  object
#  6   Fulfill Via                   10324 non-null  object
#  7   Vendor INCO Term              10324 non-null  object
#  8   Shipment Mode                 9964 non-null   object
#  9   PQ First Sent to Client Date  10324 non-null  object
#  10  PO Sent to Vendor Date        10324 non-null  object
#  11  Scheduled Delivery Date       10324 non-null  object
# ...

# %%
df.nunique()
# Out:
# Project Code                     142
# PQ #                            1237
# PO / SO #                       6233
# ASN/DN #                        7030
# Country                           43
# Managed By                         4
# Fulfill Via                        2
# Vendor INCO Term                   8
# Shipment Mode                      4
# PQ First Sent to Client Date     765
# PO Sent to Vendor Date           897
# Scheduled Delivery Date         2006
# Delivered to Client Date        2093
# Delivery Recorded Date          2042
# Product Group                      5
# Sub Classification                 6
# Vendor                            73
# Item Description                 184
# Molecule/Test Type                86
# Brand                             48
# Dosage                            54
# Dosage Form                       17
# Unit of Measure (Per Pack)        31
# Line Item Quantity              5065
# Line Item Value                 8741
# ...
